# %% [markdown]
# # Forecasting Net Prophet
#
# You’re a growth analyst at [MercadoLibre](http://investor.mercadolibre.com/about-us). With over 200 million users, MercadoLibre is the most popular e-commerce site in Latin America. You've been tasked with analyzing the company's financial and user data in clever ways to make the company grow. So, you want to find out if the ability to predict search traffic can translate into the ability to successfully trade the stock.
#
# The instructions for this Challenge are divided into four steps, as follows:
#
# * Step 1: Find unusual patterns in hourly Google search traffic
#
# * Step 2: Mine the search traffic data for seasonality
#
# * Step 3: Relate the search traffic to stock price patterns
#
# * Step 4: Create a time series model with Prophet
#
# The following subsections detail these steps.

# %% [markdown]
# ## Install and import the required libraries and dependencies

# %%
# Install the required libraries
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from prophet) (1.2.2)
# Requirement already satisfied: numpy>=1.15.4 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from prophet) (3.8.0)
# Requirement already satisfied: pandas>=1.0.4 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from prophet) (2.1.4)
# Requirement already satisfied: holidays>=0.25 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from prophet) (0.47)
# Requirement already satisfied: tqdm>=4.36.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from prophet) (4.65.0)
# Requirement already satisfied: importlib-resources in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from prophet) (6.4.0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.0)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pandas>=1.0.4->prophet) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pandas>=1.0.4->prophet) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)

# %%
# Import the required libraries and dependencies
import pandas as pd
from prophet import Prophet
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
# Ignore warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ## Step 1: Find Unusual Patterns in Hourly Google Search Traffic
#
# The data science manager asks if the Google search traffic for the company links to any financial events at the company. Or, does the search traffic data just present random noise? To answer this question, pick out any unusual patterns in the Google search data for the company, and connect them to the corporate financial events.
#
# To do so, complete the following steps:
#
# 1. Read the search data into a DataFrame, and then slice the data to just the month of May 2020. (During this month, MercadoLibre released its quarterly financial results.) Visualize the results. Do any unusual patterns exist?
#
# 2. Calculate the total search traffic for the month, and then compare the value to the monthly median across all months. Did the Google search traffic increase during the month that MercadoLibre released its financial results?

# %% [markdown]
# #### Step 1: Read the search data into a DataFrame, and then slice the data to just the month of May 2020. (During this month, MercadoLibre released its quarterly financial results.) Visualize the results. Do any unusual patterns exist?

# %%
# Store the data in a Pandas DataFrame
# Set the "Date" column as the Datetime Index.

df_mercado_trends = pd.read_csv(
    "https://static.bc-edx.com/ai/ail-v-1-0/m8/lms/datasets/google_hourly_search_trends.csv",
    index_col='Date',
    parse_dates=True
).dropna()

# Review the first and last five rows of the DataFrame
display(df_mercado_trends.head())
display(df_mercado_trends.tail())
# Out:
# /var/folders/pb/8hnpgywn78g6wf2yhwwwcpnh0000gn/T/ipykernel_4155/1669825240.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_mercado_trends = pd.read_csv(
#                      Search Trends
# Date
# 2016-06-01 00:00:00             97
# 2016-06-01 01:00:00             92
# 2016-06-01 02:00:00             76
# 2016-06-01 03:00:00             60
# 2016-06-01 04:00:00             38
#                      Search Trends
# Date
# 2020-09-07 20:00:00             71
# 2020-09-07 21:00:00             83
# 2020-09-07 22:00:00             96
# 2020-09-07 23:00:00             97
# 2020-09-08 00:00:00             96

# %%
#Format index to datetime
df_mercado_trends.index = pd.to_datetime(df_mercado_trends.index)

# %%
# Review the data types of the DataFrame using the info function
df_mercado_trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 37106 entries, 2016-06-01 00:00:00 to 2020-09-08 00:00:00
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Search Trends  37106 non-null  int64
# dtypes: int64(1)
# memory usage: 579.8 KB

# %%
# Slice the DataFrame to just the month of May 2020
#may_2020_df = df_mercado_trends[(df_mercado_trends.index >= '2020-05-01') & (df_mercado_trends.index < '2020-06-01')]
may_2020_df = df_mercado_trends.loc['2020-5'] # Shortend version

# Plot to visualize the data for May 2020
# Set axis
x_axis = may_2020_df.index
y_axis = may_2020_df['Search Trends']
figure1 = plt.plot(x_axis, y_axis)

# Set x-axis tick labels
plt.xticks(rotation=45)  # Rotate the labels for better readability
plt.xlabel('Date')  # Set x-axis label

# Set tight layout and show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Step 2: Calculate the total search traffic for the month, and then compare the value to the monthly median across all months. Did the Google search traffic increase during the month that MercadoLibre released its financial results?

# %%
# Calculate the sum of the total search traffic for May 2020
may_traffic_totals = may_2020_df.sum()

# View the traffic_may_2020 value
may_traffic_totals
# Out:
# Search Trends    38181
# dtype: int64

# %%
# Calcluate the monthly median search traffic across all months
# Group the DataFrame by index year and then index month, chain the sum and then the median functions
year_month_grouped = df_mercado_trends.groupby([df_mercado_trends.index.year, df_mercado_trends.index.month])

# Using grouper, which works too
#grouped_by_month_year = df_mercado_trends.groupby(pd.Grouper(freq='M'))

# Calculate sum for each month
monthly_totals = year_month_grouped.sum()

# Calculate monthly median of months
monthly_median = monthly_totals.median()

# Display totals by month
print(monthly_totals)

# Display monthly median
print(f'The monthly median is: {monthly_median}')
# Out:
#            Search Trends
# Date Date
# 2016 6             33196
#      7             33898
#      8             34459
#      9             32376
#      10            32334
#      11            33793
#      12            33789
# 2017 1             32984
#      2             31901
#      3             35363
#      4             32522
#      5             33216
#      6             34211
#      7             34988
#      8             36113
#      9             33693
#      10            32842
#      11            35144
#      12            35420
# 2018 1             37347
#      2             33748
#      3             36051
#      4             35283
#      5             35309
#      6             34115
#      7             35927
#      8             37012
#      9             34037
#      10            35879
#      11            34686
#      12            35245
# 2019 1             38505
#      2             34129
#      3             37331
#      4             35505
#      5             34983
#      6             36120
#      7             37089
#      8             37540
#      9             35201
#      10            37212
#      11            36280
#      12            37825
# 2020 1             39177
#      2             30838
#      3             24805
#      4             35229
#      5             38181
#      6             35758
#      7             35620
#      8             33530
#      9              8126
# The monthly median is: Search Trends    35172.5
# dtype: float64

# %%
# Compare the seach traffic for the month of May 2020 to the overall monthly median value
may_traffic_totals/monthly_median
# Out:
# Search Trends    1.085536
# dtype: float64

# %% [markdown]
# ##### Answer the following question:

# %% [markdown]
# **Question:** Did the Google search traffic increase during the month that MercadoLibre released its financial results?
#
# **Answer:** Data revealed that traffic increased by 8.55% during the month of May, 2020.

# %% [markdown]
# ## Step 2: Mine the Search Traffic Data for Seasonality
#
# Marketing realizes that they can use the hourly search data, too. If they can track and predict interest in the company and its platform for any time of day, they can focus their marketing efforts around the times that have the most traffic. This will get a greater return on investment (ROI) from their marketing budget.
#
# To that end, you want to mine the search traffic data for predictable seasonal patterns of interest in the company. To do so, complete the following steps:
#
# 1. Group the hourly search data to plot the average traffic by the hour of day. Does the search traffic peak at a particular time of day or is it relatively consistent?
#
# 2. Group the hourly search data to plot the average traffic by the day of the week (for example, Monday vs. Friday). Does the search traffic get busiest on any particular day of the week?
#
# 3. Group the hourly search data to plot the average traffic by the week of the year. Does the search traffic tend to increase during the winter holiday period (weeks 40 through 52)?

# %% [markdown]
# #### Step 1: Group the hourly search data to plot the average traffic by the hour of the day.

# %%
# Group the hourly search data to plot the average traffic by the hour of the day, using `df.index.hour`
hourly_grouped = df_mercado_trends.groupby(df_mercado_trends.index.hour)
average_by_hour = hourly_grouped.mean()
average_by_hour
# Out:
#       Search Trends
# Date
# 0         88.324289
# 1         84.408150
# 2         76.419793
# 3         61.954075
# 4         43.720569
# 5         26.406856
# 6         14.459897
# 7          8.371928
# 8          6.150712
# 9          7.384864
# 10        12.699871
# 11        22.523286
# 12        33.452781
# 13        41.648771
# 14        47.807891
# 15        51.516818
# 16        53.333765
# 17        55.810479
# 18        57.659767
# 19        59.500000
# 20        62.643596
# 21        69.803364
# 22        80.777490
# 23        88.258732

# %%
# Plot average by hour
average_by_hour.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### Step 2: Group the hourly search data to plot the average traffic by the day of the week (for example, Monday vs. Friday).

# %%
# Group the hourly search data to plot the average traffic by the day of week, using `df.index.isocalendar().day`.
day_grouped_mean = df_mercado_trends.groupby([df_mercado_trends.index.isocalendar().day])
day_mean = day_grouped_mean.mean()
day_mean.head(10)
# Out:
#      Search Trends
# day
# 1        49.522813
# 2        50.571672
# 3        50.219604
# 4        49.699661
# 5        48.621041
# 6        45.125377
# 7        43.151207

# %%
# Display mean by day of week
day_mean.plot()
# Out:
# <Axes: xlabel='day'>

# %%
# Examine totals grouped by day of the week
day_grouped_sum = df_mercado_trends.groupby([df_mercado_trends.index.isocalendar().day])
day_sum = day_grouped_sum.sum()
day_sum
# Out:
#      Search Trends
# day
# 1           262669
# 2           267069
# 3           266415
# 4           263607
# 5           257886
# 6           239345
# 7           228874

# %%
# Plot sum by day of week
day_sum.plot()
# Out:
# <Axes: xlabel='day'>

# %%
# Examine average grouped by day of the month
day_grouped_31_mean = df_mercado_trends.groupby(df_mercado_trends.index.day)
average_by_day_31 = day_grouped_31_mean.mean()
average_by_day_31
# Out:
#       Search Trends
# Date
# 1         45.505719
# 2         48.039216
# 3         48.309641
# 4         48.528595
# 5         49.142157
# 6         48.863562
# 7         48.650327
# 8         47.848460
# 9         47.614167
# 10        48.101667
# 11        48.155229
# 12        48.122549
# 13        48.924020
# 14        48.428105
# 15        48.425654
# 16        48.382353
# 17        48.528595
# 18        48.660948
# 19        48.411765
# 20        48.004902
# 21        48.242647
# 22        48.318627
# 23        47.763072
# 24        47.051471
# 25        46.968137
# 26        47.928393
# 27        48.211667
# 28        48.969167
# 29        48.653369
# 30        47.935284
# 31        46.763889

# %%
# Plot mean by day of month
average_by_day_31.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Examine totals grouped by day of the month
day_grouped_31_sum = df_mercado_trends.groupby(df_mercado_trends.index.day)
sum_by_day_31 = day_grouped_31_sum.sum()
sum_by_day_31
# Out:
#       Search Trends
# Date
# 1             55699
# 2             58800
# 3             59131
# 4             59399
# 5             60150
# 6             59809
# 7             59548
# 8             57466
# 9             57137
# 10            57722
# 11            58942
# 12            58902
# 13            59883
# 14            59276
# 15            59273
# 16            59220
# 17            59399
# 18            59561
# 19            59256
# 20            58758
# 21            59049
# 22            59142
# 23            58462
# 24            57591
# 25            57489
# 26            57562
# 27            57854
# 28            58763
# 29            54881
# 30            54071
# 31            33670

# %%
# Plot sum by day of month
sum_by_day_31.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### Step 3: Group the hourly search data to plot the average traffic by the week of the year.

# %%
# Group the hourly search data to plot the average traffic by the week of the year using `df.index.isocalendar().week`.
week_grouped_mean = df_mercado_trends.groupby(df_mercado_trends.index.isocalendar().week)

# Plot mean by week of year
week_avg = week_grouped_mean.mean().plot()

# %%
# Group the hourly search data to plot the sum traffic by the week of the year using `df.index.isocalendar().week`.
week_grouped_sum = df_mercado_trends.groupby(df_mercado_trends.index.isocalendar().week)

# Plot sum by week of year
week_sum = week_grouped_sum.sum().plot()

# %% [markdown]
# ##### Answer the following question:

# %% [markdown]
# **Question:** Are there any time based trends that you can see in the data?
#
# **Answer:** The first noticable trend revealed by data is hourly search traffic dips to a significant low at hour 8 while it peaks at hours 23 and 0. The second noticable trend revealed by data is that traffic is higher during days 1-4 and then declines significantly for days 6 and 7. The third noticable trend revealed by data is that traffic totals peak during weeks that correspond with the months of June, July, and August while week 10 shows a steep decline.

# %% [markdown]
# ## Step 3: Relate the Search Traffic to Stock Price Patterns
#
# You mention your work on the search traffic data during a meeting with people in the finance group at the company. They want to know if any relationship between the search data and the company stock price exists, and they ask if you can investigate.
#
# To do so, complete the following steps:
#
# 1. Read in and plot the stock price data. Concatenate the stock price data to the search data in a single DataFrame.
#
# 2. Market events emerged during the year of 2020 that many companies found difficult. But, after the initial shock to global financial markets, new customers and revenue increased for e-commerce platforms. Slice the data to just the first half of 2020 (`2020-01` to `2020-06` in the DataFrame), and then plot the data. Do both time series indicate a common trend that’s consistent with this narrative?
#
# 3. Create a new column in the DataFrame named “Lagged Search Trends” that offsets, or shifts, the search traffic by one hour. Create two additional columns:
#
#     * “Stock Volatility”, which holds an exponentially weighted four-hour rolling average of the company’s stock volatility
#
#     * “Hourly Stock Return”, which holds the percent change of the company's stock price on an hourly basis
#
# 4. Review the time series correlation, and then answer the following question: Does a predictable relationship exist between the lagged search traffic and the stock volatility or between the lagged search traffic and the stock price returns?

# %% [markdown]
# #### Step 1: Read in and plot the stock price data. Concatenate the stock price data to the search data in a single DataFrame.

# %%
# Upload the "mercado_stock_price.csv" file into Colab, then store in a Pandas DataFrame
# Set the "date" column as the Datetime Index.
df_mercado_stock = pd.read_csv(
    "https://static.bc-edx.com/ai/ail-v-1-0/m8/lms/datasets/mercado_stock_price.csv",
    index_col="date",
    parse_dates=True
).dropna()

# View the first and last five rows of the DataFrame
display(df_mercado_stock.head())
display(df_mercado_stock.tail())
# Out:
#                       close
# date
# 2015-01-02 09:00:00  127.67
# 2015-01-02 10:00:00  125.44
# 2015-01-02 11:00:00  125.57
# 2015-01-02 12:00:00  125.40
# 2015-01-02 13:00:00  125.17
#                         close
# date
# 2020-07-31 11:00:00  1105.780
# 2020-07-31 12:00:00  1087.925
# 2020-07-31 13:00:00  1095.800
# 2020-07-31 14:00:00  1110.650
# 2020-07-31 15:00:00  1122.510

# %%
# Visualize the closing price of the df_mercado_stock DataFrame
df_mercado_stock["close"].plot(
    title="Historial Mercado Closing Prices",
    figsize=[20, 10]
)
# Out:
# <Axes: title={'center': 'Historial Mercado Closing Prices'}, xlabel='date'>

# %%
# Concatenate the df_mercado_stock DataFrame with the df_mercado_trends DataFrame
# Concatenate the DataFrame by columns (axis=1), and drop any rows with only one column of data
mercado_stock_trends_df = pd.concat([df_mercado_stock, df_mercado_trends], axis=1)
mercado_stock_trends_df.dropna(inplace=True)

# View the first and last five rows of the DataFrame
mercado_stock_trends_df
# Out:
#                         close  Search Trends
# 2016-06-01 09:00:00   135.160            6.0
# 2016-06-01 10:00:00   136.630           12.0
# 2016-06-01 11:00:00   136.560           22.0
# 2016-06-01 12:00:00   136.420           33.0
# 2016-06-01 13:00:00   136.100           40.0
# ...                       ...            ...
# 2020-07-31 11:00:00  1105.780           20.0
# 2020-07-31 12:00:00  1087.925           32.0
# 2020-07-31 13:00:00  1095.800           41.0
# 2020-07-31 14:00:00  1110.650           47.0
# 2020-07-31 15:00:00  1122.510           53.0
#
# [7067 rows x 2 columns]

# %% [markdown]
# #### Step 2: Market events emerged during the year of 2020 that many companies found difficult. But, after the initial shock to global financial markets, new customers and revenue increased for e-commerce platforms. Slice the data to just the first half of 2020 (`2020-01` to `2020-06` in the DataFrame), and then plot the data. Do both time series indicate a common trend that’s consistent with this narrative?

# %%
# For the combined dataframe, slice to just the first half of 2020 (2020-01 through 2020-06)
first_half_2020_combined_mercado = mercado_stock_trends_df.loc['2020-1' : '2020-6']

# View the first and last five rows of first_half_2020 DataFrame
first_half_2020_combined_mercado
# Out:
#                        close  Search Trends
# 2020-01-02 09:00:00  601.085            9.0
# 2020-01-02 10:00:00  601.290           14.0
# 2020-01-02 11:00:00  615.410           25.0
# 2020-01-02 12:00:00  611.400           37.0
# 2020-01-02 13:00:00  611.830           50.0
# ...                      ...            ...
# 2020-06-30 11:00:00  976.170           17.0
# 2020-06-30 12:00:00  977.500           27.0
# 2020-06-30 13:00:00  973.230           37.0
# 2020-06-30 14:00:00  976.500           45.0
# 2020-06-30 15:00:00  984.930           51.0
#
# [807 rows x 2 columns]

# %%
# Visualize the close and Search Trends data
# Plot each column on a separate axes using the following syntax
# `plot(subplots=True)`
first_half_2020_combined_mercado[['close', 'Search Trends']].plot(
    subplots=True,
    figsize=[20, 10]
)
plt.show()

# %% [markdown]
# ##### Answer the following question:

# %% [markdown]
# **Question:** Do both time series indicate a common trend that’s consistent with this narrative?
#
# **Answer:** Stock price data is most representative of this narrative with a decline and then recovery beyond pre-shock prices. Search data shows a reduction in activity that did not return to pre-shock levels.

# %% [markdown]
# #### Step 3: Create a new column in the DataFrame named “Lagged Search Trends” that offsets, or shifts, the search traffic by one hour. Create two additional columns:
#
# * “Stock Volatility”, which holds an exponentially weighted four-hour rolling average of the company’s stock volatility
#
# * “Hourly Stock Return”, which holds the percent change of the company's stock price on an hourly basis

# %%
# Create a new column in the mercado_stock_trends_df DataFrame called Lagged Search Trends
# This column should shift the Search Trends information by one hour
mercado_stock_trends_df['Lagged Search Trends'] = mercado_stock_trends_df['Search Trends'].shift(1)
mercado_stock_trends_df.dropna(inplace=True)
mercado_stock_trends_df
# Out:
#                         close  Search Trends  Lagged Search Trends
# 2016-06-01 10:00:00   136.630           12.0                   6.0
# 2016-06-01 11:00:00   136.560           22.0                  12.0
# 2016-06-01 12:00:00   136.420           33.0                  22.0
# 2016-06-01 13:00:00   136.100           40.0                  33.0
# 2016-06-01 14:00:00   137.030           45.0                  40.0
# ...                       ...            ...                   ...
# 2020-07-31 11:00:00  1105.780           20.0                  11.0
# 2020-07-31 12:00:00  1087.925           32.0                  20.0
# 2020-07-31 13:00:00  1095.800           41.0                  32.0
# 2020-07-31 14:00:00  1110.650           47.0                  41.0
# 2020-07-31 15:00:00  1122.510           53.0                  47.0
#
# [7066 rows x 3 columns]

# %%
# Create a new column in the mercado_stock_trends_df DataFrame called Stock Volatility
# This column should calculate the standard deviation of the closing stock price return data over a 4 period rolling window
mercado_stock_trends_df['Stock Volatility'] = mercado_stock_trends_df['close'].pct_change().rolling(window=4).std()
mercado_stock_trends_df.dropna(inplace=True)
mercado_stock_trends_df
# Out:
#                         close  Search Trends  Lagged Search Trends  \
# 2016-06-01 14:00:00   137.030           45.0                  40.0
# 2016-06-01 15:00:00   136.270           48.0                  45.0
# 2016-06-02 09:00:00   136.000            7.0                  48.0
# 2016-06-02 10:00:00   136.830           14.0                   7.0
# 2016-06-02 11:00:00   136.220           24.0                  14.0
# ...                       ...            ...                   ...
# 2020-07-31 11:00:00  1105.780           20.0                  11.0
# 2020-07-31 12:00:00  1087.925           32.0                  20.0
# 2020-07-31 13:00:00  1095.800           41.0                  32.0
# 2020-07-31 14:00:00  1110.650           47.0                  41.0
# 2020-07-31 15:00:00  1122.510           53.0                  47.0
#
#                      Stock Volatility
# 2016-06-01 14:00:00          0.004137
# 2016-06-01 15:00:00          0.005257
# 2016-06-02 09:00:00          0.005309
# 2016-06-02 10:00:00          0.006091
# 2016-06-02 11:00:00          0.005265
# ...                               ...
# 2020-07-31 11:00:00          0.012837
# 2020-07-31 12:00:00          0.013549
# 2020-07-31 13:00:00          0.013295
# 2020-07-31 14:00:00          0.013001
# 2020-07-31 15:00:00          0.013566
#
# [7062 rows x 4 columns]

# %%
# Visualize the stock volatility
mercado_stock_trends_df[['Stock Volatility']].plot(
    figsize=[20, 10]
)
plt.show()

# %% [markdown]
# **Solution Note:** Note how volatility spiked, and tended to stay high, during the first half of 2020. This is a common characteristic of volatility in stock returns worldwide: high volatility days tend to be followed by yet more high volatility days. When it rains, it pours.

# %%
# Create a new column in the mercado_stock_trends_df DataFrame called Hourly Stock Return
# This column should calculate hourly return percentage of the closing price
mercado_stock_trends_df['Hourly Stock Return'] = mercado_stock_trends_df['close'].pct_change()
mercado_stock_trends_df.dropna(inplace=True)

# %%
# View the first and last five rows of the mercado_stock_trends_df DataFrame
mercado_stock_trends_df
# Out:
#                         close  Search Trends  Lagged Search Trends  \
# 2016-06-01 15:00:00   136.270           48.0                  45.0
# 2016-06-02 09:00:00   136.000            7.0                  48.0
# 2016-06-02 10:00:00   136.830           14.0                   7.0
# 2016-06-02 11:00:00   136.220           24.0                  14.0
# 2016-06-02 12:00:00   136.500           35.0                  24.0
# ...                       ...            ...                   ...
# 2020-07-31 11:00:00  1105.780           20.0                  11.0
# 2020-07-31 12:00:00  1087.925           32.0                  20.0
# 2020-07-31 13:00:00  1095.800           41.0                  32.0
# 2020-07-31 14:00:00  1110.650           47.0                  41.0
# 2020-07-31 15:00:00  1122.510           53.0                  47.0
#
#                      Stock Volatility  Hourly Stock Return
# 2016-06-01 15:00:00          0.005257            -0.005546
# 2016-06-02 09:00:00          0.005309            -0.001981
# 2016-06-02 10:00:00          0.006091             0.006103
# 2016-06-02 11:00:00          0.005265            -0.004458
# 2016-06-02 12:00:00          0.004638             0.002055
# ...                               ...                  ...
# 2020-07-31 11:00:00          0.012837             0.006380
# 2020-07-31 12:00:00          0.013549            -0.016147
# 2020-07-31 13:00:00          0.013295             0.007239
# 2020-07-31 14:00:00          0.013001             0.013552
# 2020-07-31 15:00:00          0.013566             0.010678
#
# [7061 rows x 5 columns]

# %% [markdown]
# #### Step 4: Review the time series correlation, and then answer the following question: Does a predictable relationship exist between the lagged search traffic and the stock volatility or between the lagged search traffic and the stock price returns?

# %%
# Construct correlation table of Stock Volatility, Lagged Search Trends, and Hourly Stock Return
mercado_stock_trends_df[['Stock Volatility', 'Lagged Search Trends', 'Hourly Stock Return']].corr()
# Out:
#                       Stock Volatility  Lagged Search Trends  \
# Stock Volatility              1.000000             -0.148913
# Lagged Search Trends         -0.148913              1.000000
# Hourly Stock Return           0.061465              0.018089
#
#                       Hourly Stock Return
# Stock Volatility                 0.061465
# Lagged Search Trends             0.018089
# Hourly Stock Return              1.000000

# %% [markdown]
# ##### Answer the following question:

# %% [markdown]
# **Question:** Does a predictable relationship exist between the lagged search traffic and the stock volatility or between the lagged search traffic and the stock price returns?
#
# **Answer:** No, all correlations are extremely weak.

# %% [markdown]
# ## Step 4: Create a Time Series Model with Prophet
#
# Now, you need to produce a time series model that analyzes and forecasts patterns in the hourly search data. To do so, complete the following steps:
#
# 1. Set up the Google search data for a Prophet forecasting model.
#
# 2. After estimating the model, plot the forecast. How's the near-term forecast for the popularity of MercadoLibre?
#
# 3. Plot the individual time series components of the model to answer the following questions:
#
#     * What time of day exhibits the greatest popularity?
#
#     * Which day of the week gets the most search traffic?
#
#     * What's the lowest point for search traffic in the calendar year?

# %% [markdown]
# #### Step 1: Set up the Google search data for a Prophet forecasting model.

# %%
# Using the df_mercado_trends DataFrame, reset the index so the date information is no longer the index
df_mercado_trends = df_mercado_trends.reset_index()

# Label the columns ds and y so that the syntax is recognized by Prophet
df_mercado_trends.rename(columns={'Date':'ds','Search Trends':'y'}, inplace=True)

# Drop an NaN values from the prophet_df DataFrame
df_mercado_trends.dropna()

# View the first and last five rows of the mercado_prophet_df DataFrame
df_mercado_trends
# Out:
#                        ds   y
# 0     2016-06-01 00:00:00  97
# 1     2016-06-01 01:00:00  92
# 2     2016-06-01 02:00:00  76
# 3     2016-06-01 03:00:00  60
# 4     2016-06-01 04:00:00  38
# ...                   ...  ..
# 37101 2020-09-07 20:00:00  71
# 37102 2020-09-07 21:00:00  83
# 37103 2020-09-07 22:00:00  96
# 37104 2020-09-07 23:00:00  97
# 37105 2020-09-08 00:00:00  96
#
# [37106 rows x 2 columns]

# %%
# Call the Prophet function, store as an object
mercado_model = Prophet()

# %%
# Fit the time-series model.
mercado_model.fit(df_mercado_trends)
# Out:
# 11:45:52 - cmdstanpy - INFO - Chain [1] start processing
# 11:46:01 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Create a future dataframe to hold predictions
# Make the prediction go out as far as 2000 hours (approx 80 days)
mercado_future = mercado_model.make_future_dataframe(periods = 2000, freq = 'h')

# View the last five rows of the future_mercado_trends DataFrame
mercado_future.tail(5)
# Out:
#                        ds
# 39101 2020-11-30 04:00:00
# 39102 2020-11-30 05:00:00
# 39103 2020-11-30 06:00:00
# 39104 2020-11-30 07:00:00
# 39105 2020-11-30 08:00:00

# %%
# Make the predictions for the trend data using the future_mercado_trends DataFrame
mercado_forecast = mercado_model.predict(mercado_future)

# Display the first five rows of the forecast_mercado_trends DataFrame
mercado_forecast.head(5)
# Out:
#                        ds      trend  yhat_lower  yhat_upper  trend_lower  \
# 39056 2020-11-28 07:00:00  44.855900   -5.243209   12.338829    43.830067
# 39057 2020-11-28 08:00:00  44.855109   -7.024010    9.750130    43.828430
# 39058 2020-11-28 09:00:00  44.854318   -4.984049   11.782976    43.826818
# 39059 2020-11-28 10:00:00  44.853527    0.839596   17.817376    43.825463
# 39060 2020-11-28 11:00:00  44.852736    9.857601   27.219676    43.824107
# 39061 2020-11-28 12:00:00  44.851944   18.488680   36.179065    43.822751
# 39062 2020-11-28 13:00:00  44.851153   27.383689   44.198668    43.821395
# 39063 2020-11-28 14:00:00  44.850362   34.016668   50.882027    43.820039
# 39064 2020-11-28 15:00:00  44.849571   37.778808   54.290516    43.818683
# 39065 2020-11-28 16:00:00  44.848780   39.692025   56.711746    43.817327
# 39066 2020-11-28 17:00:00  44.847989   40.660786   57.897161    43.815971
# 39067 2020-11-28 18:00:00  44.847198   41.141115   58.183608    43.814616
# 39068 2020-11-28 19:00:00  44.846407   44.196346   61.153870    43.813260
# 39069 2020-11-28 20:00:00  44.845615   48.201313   65.759927    43.811904
# 39070 2020-11-28 21:00:00  44.844824   55.863307   73.201824    43.810455
# 39071 2020-11-28 22:00:00  44.844033   63.777336   80.288740    43.808391
# 39072 2020-11-28 23:00:00  44.843242   70.436466   87.430425    43.806326
# 39073 2020-11-29 00:00:00  44.842451   73.006165   90.630263    43.804261
# 39074 2020-11-29 01:00:00  44.841660   69.196288   86.171942    43.802197
# 39075 2020-11-29 02:00:00  44.840869   59.901861   76.522157    43.800132
# 39076 2020-11-29 03:00:00  44.840078   44.285592   61.528767    43.798076
# 39077 2020-11-29 04:00:00  44.839287   26.700233   43.572153    43.796020
# 39078 2020-11-29 05:00:00  44.838495   10.226301   27.566257    43.793964
# 39079 2020-11-29 06:00:00  44.837704   -2.480083   15.473567    43.792009
# 39080 2020-11-29 07:00:00  44.836913   -9.230983    8.012682    43.790394
# 39081 2020-11-29 08:00:00  44.836122  -11.598078    5.165532    43.788801
# 39082 2020-11-29 09:00:00  44.835331   -9.506164    7.648304    43.787207
# 39083 2020-11-29 10:00:00  44.834540   -3.285939   14.220931    43.785614
# 39084 2020-11-29 11:00:00  44.833749    5.854036   23.157478    43.784021
# 39085 2020-11-29 12:00:00  44.832958   15.886849   32.556946    43.782428
# 39086 2020-11-29 13:00:00  44.832167   24.626644   41.709858    43.780834
# 39087 2020-11-29 14:00:00  44.831375   31.254116   48.335253    43.779241
# 39088 2020-11-29 15:00:00  44.830584   34.849003   52.133291    43.777648
# 39089 2020-11-29 16:00:00  44.829793   37.495409   54.359887    43.776054
# 39090 2020-11-29 17:00:00  44.829002   39.569094   56.142988    43.774461
# 39091 2020-11-29 18:00:00  44.828211   41.549915   57.827404    43.771629
# 39092 2020-11-29 19:00:00  44.827420   43.694430   60.231189    43.769677
# 39093 2020-11-29 20:00:00  44.826629   48.091025   64.982584    43.767740
# 39094 2020-11-29 21:00:00  44.825838   55.964412   73.049770    43.765965
# 39095 2020-11-29 22:00:00  44.825047   65.001978   81.203942    43.764249
# 39096 2020-11-29 23:00:00  44.824255   71.859846   89.491891    43.762533
# 39097 2020-11-30 00:00:00  44.823464   75.940660   92.910803    43.760818
# 39098 2020-11-30 01:00:00  44.822673   72.647513   89.362812    43.759102
# 39099 2020-11-30 02:00:00  44.821882   61.998275   79.339524    43.757386
# 39100 2020-11-30 03:00:00  44.821091   47.540094   64.900082    43.755671
# 39101 2020-11-30 04:00:00  44.820300   30.655883   47.259640    43.753955
# 39102 2020-11-30 05:00:00  44.819509   15.224490   32.171194    43.752239
# 39103 2020-11-30 06:00:00  44.818718    3.693682   20.093640    43.750524
# 39104 2020-11-30 07:00:00  44.817927   -4.156768   12.989527    43.748808
# 39105 2020-11-30 08:00:00  44.817135   -5.969510   11.648060    43.747093
#
#        trend_upper  additive_terms  additive_terms_lower  \
# 39056    45.786153      -41.022842            -41.022842
# 39057    45.785915      -43.774817            -43.774817
# 39058    45.785676      -41.653268            -41.653268
# 39059    45.785437      -35.461693            -35.461693
# 39060    45.785199      -26.663758            -26.663758
# 39061    45.784960      -17.156067            -17.156067
# 39062    45.784721       -8.719122             -8.719122
# 39063    45.784483       -2.456737             -2.456737
# 39064    45.784244        1.420087              1.420087
# 39065    45.784005        3.408070              3.408070
# 39066    45.783767        4.387918              4.387918
# 39067    45.783528        5.428075              5.428075
# 39068    45.783289        7.686298              7.686298
# 39069    45.783051       12.141311             12.141311
# 39070    45.782812       19.021164             19.021164
# 39071    45.782573       27.215886             27.215886
# 39072    45.782335       34.232925             34.232925
# 39073    45.782096       37.017928             37.017928
# 39074    45.781857       33.333363             33.333363
# 39075    45.781618       22.888425             22.888425
# 39076    45.781380        7.510217              7.510217
# 39077    45.781141       -9.703640             -9.703640
# 39078    45.780902      -25.636622            -25.636622
# 39079    45.780664      -38.040114            -38.040114
# 39080    45.780425      -45.722733            -45.722733
# 39081    45.780186      -48.297620            -48.297620
# 39082    45.780002      -45.963175            -45.963175
# 39083    45.780117      -39.523251            -39.523251
# 39084    45.780233      -30.442224            -30.442224
# 39085    45.780348      -20.617761            -20.617761
# 39086    45.780463      -11.831773            -11.831773
# 39087    45.780578       -5.189826             -5.189826
# 39088    45.780693       -0.904996             -0.904996
# 39089    45.780808        1.517046              1.517046
# 39090    45.780924        2.954328              2.954328
# 39091    45.781039        4.472347              4.472347
# 39092    45.781154        7.225667              7.225667
# 39093    45.781269       12.189614             12.189614
# 39094    45.781384       19.588653             19.588653
# 39095    45.781499       28.309087             28.309087
# 39096    45.781615       35.854521             35.854521
# 39097    45.781730       39.166695             39.166695
# 39098    45.781845       36.004130             36.004130
# 39099    45.781960       26.072082             26.072082
# 39100    45.782075       11.193759             11.193759
# 39101    45.782190       -5.537028             -5.537028
# 39102    45.782305      -21.007444            -21.007444
# 39103    45.782421      -32.972400            -32.972400
# 39104    45.782536      -40.243847            -40.243847
# 39105    45.782651      -42.438026            -42.438026
#
#        additive_terms_upper      daily  ...    weekly  weekly_lower  \
# 39056            -41.022842 -40.478082  ... -1.211344     -1.211344
# 39057            -43.774817 -43.028861  ... -1.418096     -1.418096
# 39058            -41.653268 -40.696114  ... -1.634826     -1.634826
# 39059            -35.461693 -34.284209  ... -1.860662     -1.860662
# 39060            -26.663758 -25.257831  ... -2.094584     -2.094584
# 39061            -17.156067 -15.514749  ... -2.335427     -2.335427
# 39062             -8.719122  -6.836765  ... -2.581892     -2.581892
# 39063             -2.456737  -0.329121  ... -2.832550     -2.832550
# 39064              1.420087   3.795642  ... -3.085860     -3.085860
# 39065              3.408070   6.032597  ... -3.340176     -3.340176
# 39066              4.387918   7.260719  ... -3.593765     -3.593765
# 39067              5.428075   8.546645  ... -3.844822     -3.844822
# 39068              7.686298  11.046271  ... -4.091486     -4.091486
# 39069             12.141311  15.736425  ... -4.331858     -4.331858
# 39070             19.021164  22.843237  ... -4.564019     -4.564019
# 39071             27.215886  31.254819  ... -4.786052     -4.786052
# 39072             34.232925  38.476719  ... -4.996057     -4.996057
# 39073             37.017928  41.452726  ... -5.192175     -5.192175
# 39074             33.333363  37.943506  ... -5.372605     -5.372605
# 39075             22.888425  27.656533  ... -5.535624     -5.535624
# 39076              7.510217  12.417280  ... -5.679604     -5.679604
# 39077             -9.703640  -4.678139  ... -5.803035     -5.803035
# 39078            -25.636622 -20.514583  ... -5.904536     -5.904536
# 39079            -38.040114 -32.844667  ... -5.982875     -5.982875
# 39080            -45.722733 -40.478082  ... -6.036980     -6.036980
# 39081            -48.297620 -43.028861  ... -6.065957     -6.065957
# 39082            -45.963175 -40.696114  ... -6.069095     -6.069095
# 39083            -39.523251 -34.284209  ... -6.045881     -6.045881
# 39084            -30.442224 -25.257831  ... -5.996005     -5.996005
# 39085            -20.617761 -15.514749  ... -5.919364     -5.919364
# 39086            -11.831773  -6.836765  ... -5.816067     -5.816067
# 39087             -5.189826  -0.329121  ... -5.686439     -5.686439
# 39088             -0.904996   3.795642  ... -5.531013     -5.531013
# 39089              1.517046   6.032597  ... -5.350533     -5.350533
# 39090              2.954328   7.260719  ... -5.145945     -5.145945
# 39091              4.472347   8.546645  ... -4.918393     -4.918393
# 39092              7.225667  11.046271  ... -4.669204     -4.669204
# 39093             12.189614  15.736425  ... -4.399882     -4.399882
# 39094             19.588653  22.843237  ... -4.112090     -4.112090
# 39095             28.309087  31.254819  ... -3.807640     -3.807640
# 39096             35.854521  38.476719  ... -3.488471     -3.488471
# 39097             39.166695  41.452726  ... -3.156635     -3.156635
# 39098             36.004130  37.943506  ... -2.814275     -2.814275
# 39099             26.072082  27.656533  ... -2.463608     -2.463608
# 39100             11.193759  12.417280  ... -2.106902     -2.106902
# 39101             -5.537028  -4.678139  ... -1.746456     -1.746456
# 39102            -21.007444 -20.514583  ... -1.384577     -1.384577
# 39103            -32.972400 -32.844667  ... -1.023561     -1.023561
# 39104            -40.243847 -40.478082  ... -0.665669     -0.665669
# 39105            -42.438026 -43.028861  ... -0.313108     -0.313108
#
#        weekly_upper    yearly  yearly_lower  yearly_upper  \
# 39056     -1.211344  0.666584      0.666584      0.666584
# 39057     -1.418096  0.672141      0.672141      0.672141
# 39058     -1.634826  0.677672      0.677672      0.677672
# 39059     -1.860662  0.683177      0.683177      0.683177
# 39060     -2.094584  0.688656      0.688656      0.688656
# 39061     -2.335427  0.694109      0.694109      0.694109
# 39062     -2.581892  0.699535      0.699535      0.699535
# 39063     -2.832550  0.704933      0.704933      0.704933
# 39064     -3.085860  0.710305      0.710305      0.710305
# 39065     -3.340176  0.715649      0.715649      0.715649
# 39066     -3.593765  0.720965      0.720965      0.720965
# 39067     -3.844822  0.726253      0.726253      0.726253
# 39068     -4.091486  0.731512      0.731512      0.731512
# 39069     -4.331858  0.736743      0.736743      0.736743
# 39070     -4.564019  0.741946      0.741946      0.741946
# 39071     -4.786052  0.747119      0.747119      0.747119
# 39072     -4.996057  0.752263      0.752263      0.752263
# 39073     -5.192175  0.757377      0.757377      0.757377
# 39074     -5.372605  0.762462      0.762462      0.762462
# 39075     -5.535624  0.767516      0.767516      0.767516
# 39076     -5.679604  0.772541      0.772541      0.772541
# 39077     -5.803035  0.777534      0.777534      0.777534
# 39078     -5.904536  0.782497      0.782497      0.782497
# 39079     -5.982875  0.787428      0.787428      0.787428
# 39080     -6.036980  0.792329      0.792329      0.792329
# 39081     -6.065957  0.797198      0.797198      0.797198
# 39082     -6.069095  0.802035      0.802035      0.802035
# 39083     -6.045881  0.806839      0.806839      0.806839
# 39084     -5.996005  0.811612      0.811612      0.811612
# 39085     -5.919364  0.816352      0.816352      0.816352
# 39086     -5.816067  0.821059      0.821059      0.821059
# 39087     -5.686439  0.825733      0.825733      0.825733
# 39088     -5.531013  0.830374      0.830374      0.830374
# 39089     -5.350533  0.834981      0.834981      0.834981
# 39090     -5.145945  0.839555      0.839555      0.839555
# 39091     -4.918393  0.844095      0.844095      0.844095
# 39092     -4.669204  0.848600      0.848600      0.848600
# 39093     -4.399882  0.853071      0.853071      0.853071
# 39094     -4.112090  0.857507      0.857507      0.857507
# 39095     -3.807640  0.861908      0.861908      0.861908
# 39096     -3.488471  0.866274      0.866274      0.866274
# 39097     -3.156635  0.870604      0.870604      0.870604
# 39098     -2.814275  0.874899      0.874899      0.874899
# 39099     -2.463608  0.879158      0.879158      0.879158
# 39100     -2.106902  0.883380      0.883380      0.883380
# 39101     -1.746456  0.887566      0.887566      0.887566
# 39102     -1.384577  0.891716      0.891716      0.891716
# 39103     -1.023561  0.895829      0.895829      0.895829
# 39104     -0.665669  0.899905      0.899905      0.899905
# 39105     -0.313108  0.903943      0.903943      0.903943
#
#        multiplicative_terms  multiplicative_terms_lower  \
# 39056                   0.0                         0.0
# 39057                   0.0                         0.0
# 39058                   0.0                         0.0
# 39059                   0.0                         0.0
# 39060                   0.0                         0.0
# 39061                   0.0                         0.0
# 39062                   0.0                         0.0
# 39063                   0.0                         0.0
# 39064                   0.0                         0.0
# 39065                   0.0                         0.0
# 39066                   0.0                         0.0
# 39067                   0.0                         0.0
# 39068                   0.0                         0.0
# 39069                   0.0                         0.0
# 39070                   0.0                         0.0
# 39071                   0.0                         0.0
# 39072                   0.0                         0.0
# 39073                   0.0                         0.0
# 39074                   0.0                         0.0
# 39075                   0.0                         0.0
# 39076                   0.0                         0.0
# 39077                   0.0                         0.0
# 39078                   0.0                         0.0
# 39079                   0.0                         0.0
# 39080                   0.0                         0.0
# 39081                   0.0                         0.0
# 39082                   0.0                         0.0
# 39083                   0.0                         0.0
# 39084                   0.0                         0.0
# 39085                   0.0                         0.0
# 39086                   0.0                         0.0
# 39087                   0.0                         0.0
# 39088                   0.0                         0.0
# 39089                   0.0                         0.0
# 39090                   0.0                         0.0
# 39091                   0.0                         0.0
# 39092                   0.0                         0.0
# 39093                   0.0                         0.0
# 39094                   0.0                         0.0
# 39095                   0.0                         0.0
# 39096                   0.0                         0.0
# 39097                   0.0                         0.0
# 39098                   0.0                         0.0
# 39099                   0.0                         0.0
# 39100                   0.0                         0.0
# 39101                   0.0                         0.0
# 39102                   0.0                         0.0
# 39103                   0.0                         0.0
# 39104                   0.0                         0.0
# 39105                   0.0                         0.0
#
#        multiplicative_terms_upper       yhat
# 39056                         0.0   3.833058
# 39057                         0.0   1.080292
# 39058                         0.0   3.201049
# 39059                         0.0   9.391833
# 39060                         0.0  18.188977
# 39061                         0.0  27.695877
# 39062                         0.0  36.132031
# 39063                         0.0  42.393625
# 39064                         0.0  46.269658
# 39065                         0.0  48.256850
# 39066                         0.0  49.235907
# 39067                         0.0  50.275273
# 39068                         0.0  52.532704
# 39069                         0.0  56.986926
# 39070                         0.0  63.865988
# 39071                         0.0  72.059920
# 39072                         0.0  79.076167
# 39073                         0.0  81.860379
# 39074                         0.0  78.175023
# 39075                         0.0  67.729294
# 39076                         0.0  52.350294
# 39077                         0.0  35.135647
# 39078                         0.0  19.201874
# 39079                         0.0   6.797591
# 39080                         0.0  -0.885820
# 39081                         0.0  -3.461498
# 39082                         0.0  -1.127844
# 39083                         0.0   5.311289
# 39084                         0.0  14.391525
# 39085                         0.0  24.215197
# 39086                         0.0  33.000393
# 39087                         0.0  39.641549
# 39088                         0.0  43.925588
# 39089                         0.0  46.346839
# 39090                         0.0  47.783331
# 39091                         0.0  49.300558
# 39092                         0.0  52.053087
# 39093                         0.0  57.016243
# 39094                         0.0  64.414491
# 39095                         0.0  73.134133
# 39096                         0.0  80.678777
# 39097                         0.0  83.990160
# 39098                         0.0  80.826804
# 39099                         0.0  70.893964
# 39100                         0.0  56.014850
# 39101                         0.0  39.283272
# 39102                         0.0  23.812065
# 39103                         0.0  11.846318
# 39104                         0.0   4.574080
# 39105                         0.0   2.379109
#
# [50 rows x 22 columns]

# %% [markdown]
# #### Step 2: After estimating the model, plot the forecast. How's the near-term forecast for the popularity of MercadoLibre?

# %%
# Plot the Prophet predictions for the Mercado trends data
fig1 = mercado_model.plot(mercado_forecast)

# %% [markdown]
# ##### Answer the following question:

# %% [markdown]
# **Question:**  How's the near-term forecast for the popularity of MercadoLibre?
#
# **Answer:** The near-term forecast for Mercado is downward and is projected to return to near 2016 levels.

# %% [markdown]
# #### Step 3: Plot the individual time series components of the model to answer the following questions:
#
# * What time of day exhibits the greatest popularity?
#
# * Which day of the week gets the most search traffic?
#
# * What's the lowest point for search traffic in the calendar year?

# %%
# Set the index in the forecast_mercado_trends DataFrame to the ds datetime column
mercado_forecast = mercado_forecast.set_index('ds')

# %%
# View only the yhat,yhat_lower and yhat_upper columns from the DataFrame
mercado_forecast[['yhat', 'yhat_lower', 'yhat_upper']]
# Out:
#                           yhat  yhat_lower  yhat_upper
# ds
# 2016-06-01 00:00:00  89.558555   80.846596   98.270993
# 2016-06-01 01:00:00  86.005386   77.503991   94.479205
# 2016-06-01 02:00:00  75.682942   67.244551   84.035726
# 2016-06-01 03:00:00  60.416789   52.518313   68.928555
# 2016-06-01 04:00:00  43.302997   35.178570   51.397732
# ...                        ...         ...         ...
# 2020-11-30 04:00:00  39.283272   30.655883   47.259640
# 2020-11-30 05:00:00  23.812065   15.224490   32.171194
# 2020-11-30 06:00:00  11.846318    3.693682   20.093640
# 2020-11-30 07:00:00   4.574080   -4.156768   12.989527
# 2020-11-30 08:00:00   2.379109   -5.969510   11.648060
#
# [39106 rows x 3 columns]

# %% [markdown]
# Solutions Note: `yhat` represents the most likely (average) forecast, whereas `yhat_lower` and `yhat_upper` represents the worst and best case prediction (based on what are known as 95% confidence intervals).

# %%
# From the forecast_mercado_trends DataFrame, plot the data to visualize
#  the yhat, yhat_lower, and yhat_upper columns over the last 2000 hours
mercado_forecast[['yhat', 'yhat_lower', 'yhat_upper']].iloc[-2000:,:].plot(
    alpha = .5
)
# Out:
# <Axes: >

# %%
# Reset the index in the forecast_mercado_trends DataFrame
mercado_forecast = mercado_forecast.reset_index()

# %%
# Use the plot_components function to visualize the forecast results DataFrame
fig2 = mercado_model.plot_components(mercado_forecast)

# %% [markdown]
# ##### Answer the following questions:

# %% [markdown]
# **Question:** What time of day exhibits the greatest popularity?
#
# **Answer:** The most popular time of day is between 11:30 PM and 00:30 AM.

# %% [markdown]
# **Question:** Which day of week gets the most search traffic?
#
# **Answer:** Tuesday receives the most search traffic.

# %% [markdown]
# **Question:** What's the lowest point for search traffic in the calendar year?
#
# **Answer:** October is the lowest point for search traffice in a calendar year.
